# %%
#패키지 불러오기

import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp
import pandas as pd
from pandas import DataFrame
from scipy import stats

# %%
#데이터 불러오기

data1=pd.read_csv('C:/Users/HOME/Desktop/train.csv') 
data2=pd.read_csv('C:/Users/HOME/Desktop/test.csv')

# %%
#데이터 정보 확인

data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
#결측치 확인

data1.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
#변수삭제1(결측치 많은 변수들)

data_del=data1.drop(['LotFrontage','Alley','FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature','Utilities'],axis=1)

# %%
#결측치 확인2

data_del.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
#                  ..
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# BsmtFullBath      0
# BsmtHalfBath      0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# KitchenQual       0
# TotRmsAbvGrd      0
# Functional        0
# ...

# %%
data_del.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 69 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotArea          1460 non-null int64
# Street           1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# ...

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns


plt.rcParams['figure.figsize'] = [10, 6]

# %matplotlib inline

# %%
sns.boxplot(x="MSZoning", y="SalePrice", data=data_del,)

plt.show()

# %%
sns.boxplot(x="Street", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="LotShape", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="LandContour", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="LotConfig", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="LandSlope", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Neighborhood", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Condition1", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Condition2", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="BldgType", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="HouseStyle", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="OverallQual", y="SalePrice", data=data_del)

plt.show() ##순서형

# %%
sns.boxplot(x="OverallCond", y="SalePrice", data=data_del)

plt.show()  ##순서형

# %%
sns.boxplot(x="RoofStyle", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="RoofMatl", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Exterior1st", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Exterior2nd", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="MasVnrType", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="ExterQual", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="ExterCond", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Foundation", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="BsmtQual", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="BsmtCond", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="BsmtExposure", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="BsmtFinType1", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="BsmtFinType2", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Heating", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="HeatingQC", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="CentralAir", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Electrical", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="KitchenQual", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="Functional", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="PavedDrive", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="SaleType", y="SalePrice", data=data_del)

plt.show()

# %%
sns.boxplot(x="SaleCondition", y="SalePrice", data=data_del)

plt.show()
